# %% [markdown]
# <a href="https://colab.research.google.com/github/YeonKang/Tensorflow-with-Colab/blob/master/Lab10_1_ReLu_is_better_than_Sigmoid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
from time import time
import os
print(tf.__version__)
# Out:
# 2.4.1

# %% [markdown]
# **Checkpoint function**

# %%
def load(model, checkpoint_dir):
    print(" [*] Reading checkpoints...")

    ckpt = tf.train.get_checkpoint_state(checkpoint_dir)
    if ckpt :
        ckpt_name = os.path.basename(ckpt.model_checkpoint_path)
        checkpoint = tf.train.Checkpoint(dnn=model)
        checkpoint.restore(save_path=os.path.join(checkpoint_dir, ckpt_name))
        counter = int(ckpt_name.split('-')[1])
        print(" [*] Success to read {}".format(ckpt_name))
        return True, counter
    else:
        print(" [*] Failed to find a checkpoint")
        return False, 0

def check_folder(dir):
    if not os.path.exists(dir):
        os.makedirs(dir)
    return dir

# %% [markdown]
# **Data load & pre-processing function**

# %%
def load_mnist() :
    (train_data, train_labels), (test_data, test_labels) = mnist.load_data()
    train_data = np.expand_dims(train_data, axis=-1) #[N, 28, 28] -> [N, 28, 28, 1]
    test_data = np.expand_dims(test_data, axis=-1) #[N, 28, 28] -> [N, 28, 28, 1]

    train_data, test_data = normalize(train_data, test_data)

    train_labels = to_categorical(train_labels, 10) #[N,] -> [N, 10]
    test_labels = to_categorical(test_labels, 10) #[N,] -> [N, 10]

    return train_data, train_labels, test_data, test_labels

def normalize(train_data, test_data):
    train_data = train_data.astype(np.float32) / 255.0
    test_data = test_data.astype(np.float32) / 255.0

    return train_data, test_data

# %% [markdown]
# **Performance function**

# %%
def loss_fn(model, images, labels):
    logits = model(images, training=True)    
    loss = tf.reduce_mean(tf.keras.losses.categorical_crossentropy(y_pred=logits, y_true=labels, 
                                                                   from_logits=True))
    return loss

def accuracy_fn(model, images, labels):
    logits = model(images, training=False)
    prediction = tf.equal(tf.argmax(logits, -1), tf.argmax(labels, -1))
    accuracy = tf.reduce_mean(tf.cast(prediction, tf.float32))
    return accuracy

def grad(model, images, labels):
    with tf.GradientTape() as tape:
        loss = loss_fn(model, images, labels)
    return tape.gradient(loss, model.variables)

# %% [markdown]
# **Model function**

# %%
def flatten() :
    return tf.keras.layers.Flatten()

def dense(label_dim, weight_init) :
    return tf.keras.layers.Dense(units=label_dim, use_bias=True, kernel_initializer=weight_init)

def sigmoid() :
    return tf.keras.layers.Activation(tf.keras.activations.sigmoid)

# %% [markdown]
# **Create model (class version)**

# %%
class create_model_class(tf.keras.Model):
    def __init__(self, label_dim):
        super(create_model_class, self).__init__()
        weight_init = tf.keras.initializers.RandomNormal()

        self.model = tf.keras.Sequential()
        self.model.add(flatten())

        for i in range(2):
            self.model.add(dense(256, weight_init))
            self.model.add(sigmoid())

        self.model.add(dense(label_dim, weight_init))

    def call(self, x, training=None, mask=None):
        x = self.model(x)

        return x

# %% [markdown]
# **Create model (function version)**

# %%
def create_model_function(label_dim) :
    weight_init = tf.keras.initializers.RandomNormal()

    model = tf.keras.Sequential()
    model.add(flatten())

    for i in range(2) :
        model.add(dense(256, weight_init))
        model.add(sigmoid())

    model.add(dense(label_dim, weight_init))

    return model

# %% [markdown]
# **Define data & hyper-parameter**

# %%
""" dataset """
train_x, train_y, test_x, test_y = load_mnist()

""" parameters """
learning_rate = 0.001
batch_size = 128

training_epochs = 1
training_iterations = len(train_x) // batch_size

label_dim = 10

train_flag = True

""" Graph Input using Dataset API """
train_dataset = tf.data.Dataset.from_tensor_slices((train_x, train_y)).\
    shuffle(buffer_size=100000).\
    prefetch(buffer_size=batch_size).\
    batch(batch_size, drop_remainder=True)

test_dataset = tf.data.Dataset.from_tensor_slices((test_x, test_y)).\
    shuffle(buffer_size=100000).\
    prefetch(buffer_size=len(test_x)).\
    batch(len(test_x))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# **Define model & optimizer**

# %%
""" Model """
network = create_model_function(label_dim)

""" Training """
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

""" Writer """
checkpoint_dir = 'checkpoints'
logs_dir = 'logs'

model_dir = 'nn_softmax'

checkpoint_dir = os.path.join(checkpoint_dir, model_dir)
check_folder(checkpoint_dir)
checkpoint_prefix = os.path.join(checkpoint_dir, model_dir)
logs_dir = os.path.join(logs_dir, model_dir)

# %% [markdown]
# **Restore checkpoint & start train or test phase**

# %%
if train_flag :

    checkpoint = tf.train.Checkpoint(dnn=network)

    # create writer for tensorboard
    summary_writer = tf.summary.create_file_writer(logdir=logs_dir)
    start_time = time()

    # restore check-point if it exits
    could_load, checkpoint_counter = load(network, checkpoint_dir)    

    if could_load:
        start_epoch = (int)(checkpoint_counter / training_iterations)        
        counter = checkpoint_counter        
        print(" [*] Load SUCCESS")
    else:
        start_epoch = 0
        start_iteration = 0
        counter = 0
        print(" [!] Load failed...")
    
    # train phase
    with summary_writer.as_default():  # for tensorboard
        for epoch in range(start_epoch, training_epochs):
            for idx, (train_input, train_label) in enumerate(train_dataset):            
                grads = grad(network, train_input, train_label)
                optimizer.apply_gradients(grads_and_vars=zip(grads, network.variables))

                train_loss = loss_fn(network, train_input, train_label)
                train_accuracy = accuracy_fn(network, train_input, train_label)
                
                for test_input, test_label in test_dataset:                
                    test_accuracy = accuracy_fn(network, test_input, test_label)

                tf.summary.scalar(name='train_loss', data=train_loss, step=counter)
                tf.summary.scalar(name='train_accuracy', data=train_accuracy, step=counter)
                tf.summary.scalar(name='test_accuracy', data=test_accuracy, step=counter)

                print(
                    "Epoch: [%2d] [%5d/%5d] time: %4.4f, train_loss: %.8f, train_accuracy: %.4f, test_Accuracy: %.4f" \
                    % (epoch, idx, training_iterations, time() - start_time, train_loss, train_accuracy,
                       test_accuracy))
                counter += 1                
        checkpoint.save(file_prefix=checkpoint_prefix + '-{}'.format(counter))
        
# test phase      
else :
    _, _ = load(network, checkpoint_dir)
    for test_input, test_label in test_dataset:    
        test_accuracy = accuracy_fn(network, test_input, test_label)

    print("test_Accuracy: %.4f" % (test_accuracy))
# Out:
#  [*] Reading checkpoints...
#  [*] Failed to find a checkpoint
#  [!] Load failed...
# Epoch: [ 0] [    0/  468] time: 1.0281, train_loss: 2.33752322, train_accuracy: 0.0625, test_Accuracy: 0.1032
# Epoch: [ 0] [    1/  468] time: 1.2475, train_loss: 2.28256369, train_accuracy: 0.1250, test_Accuracy: 0.1010
# Epoch: [ 0] [    2/  468] time: 1.4538, train_loss: 2.24745202, train_accuracy: 0.1797, test_Accuracy: 0.1010
# Epoch: [ 0] [    3/  468] time: 1.6764, train_loss: 2.24022961, train_accuracy: 0.1484, test_Accuracy: 0.1010
# Epoch: [ 0] [    4/  468] time: 1.8919, train_loss: 2.33716989, train_accuracy: 0.0859, test_Accuracy: 0.1010
# Epoch: [ 0] [    5/  468] time: 2.1041, train_loss: 2.24934983, train_accuracy: 0.2500, test_Accuracy: 0.1857
# Epoch: [ 0] [    6/  468] time: 2.3217, train_loss: 2.26562500, train_accuracy: 0.2656, test_Accuracy: 0.2428
# Epoch: [ 0] [    7/  468] time: 2.5495, train_loss: 2.27876759, train_accuracy: 0.0938, test_Accuracy: 0.1340
# Epoch: [ 0] [    8/  468] time: 2.7518, train_loss: 2.26659441, train_accuracy: 0.1875, test_Accuracy: 0.1324
# Epoch: [ 0] [    9/  468] time: 2.9730, train_loss: 2.26850200, train_accuracy: 0.1719, test_Accuracy: 0.1759
# Epoch: [ 0] [   10/  468] time: 3.1979, train_loss: 2.24050426, train_accuracy: 0.2344, test_Accuracy: 0.2433
# Epoch: [ 0] [   11/  468] time: 3.4237, train_loss: 2.15172887, train_accuracy: 0.3359, test_Accuracy: 0.2431
# Epoch: [ 0] [   12/  468] time: 3.6401, train_loss: 2.20717168, train_accuracy: 0.1875, test_Accuracy: 0.1974
# Epoch: [ 0] [   13/  468] time: 3.8427, train_loss: 2.20020366, train_accuracy: 0.1953, test_Accuracy: 0.1934
# Epoch: [ 0] [   14/  468] time: 4.0572, train_loss: 2.18660450, train_accuracy: 0.1797, test_Accuracy: 0.2090
# Epoch: [ 0] [   15/  468] time: 4.2727, train_loss: 2.19691706, train_accuracy: 0.2734, test_Accuracy: 0.3240
# Epoch: [ 0] [   16/  468] time: 4.4932, train_loss: 2.18924713, train_accuracy: 0.3516, test_Accuracy: 0.3260
# Epoch: [ 0] [   17/  468] time: 4.6926, train_loss: 2.19971204, train_accuracy: 0.2500, test_Accuracy: 0.2585
# Epoch: [ 0] [   18/  468] time: 4.9051, train_loss: 2.12010813, train_accuracy: 0.2422, test_Accuracy: 0.2321
# Epoch: [ 0] [   19/  468] time: 5.1188, train_loss: 2.12307978, train_accuracy: 0.2578, test_Accuracy: 0.2146
# Epoch: [ 0] [   20/  468] time: 5.3257, train_loss: 2.09941530, train_accuracy: 0.2266, test_Accuracy: 0.2434
# Epoch: [ 0] [   21/  468] time: 5.5288, train_loss: 2.09763098, train_accuracy: 0.2734, test_Accuracy: 0.2985
# Epoch: [ 0] [   22/  468] time: 5.7347, train_loss: 2.08011365, train_accuracy: 0.3438, test_Accuracy: 0.3735
# Epoch: [ 0] [   23/  468] time: 5.9428, train_loss: 2.08069682, train_accuracy: 0.4062, test_Accuracy: 0.4497
# Epoch: [ 0] [   24/  468] time: 6.1522, train_loss: 2.09648180, train_accuracy: 0.3672, test_Accuracy: 0.4164
# Epoch: [ 0] [   25/  468] time: 6.3596, train_loss: 2.01080132, train_accuracy: 0.3594, test_Accuracy: 0.3450
# Epoch: [ 0] [   26/  468] time: 6.5561, train_loss: 2.01913691, train_accuracy: 0.4062, test_Accuracy: 0.3559
# Epoch: [ 0] [   27/  468] time: 6.7604, train_loss: 1.99855900, train_accuracy: 0.3906, test_Accuracy: 0.4070
# Epoch: [ 0] [   28/  468] time: 6.9672, train_loss: 1.97952795, train_accuracy: 0.4531, test_Accuracy: 0.4665
# Epoch: [ 0] [   29/  468] time: 7.1778, train_loss: 1.99415541, train_accuracy: 0.4531, test_Accuracy: 0.5180
# Epoch: [ 0] [   30/  468] time: 7.3811, train_loss: 1.94812226, train_accuracy: 0.4922, test_Accuracy: 0.5515
# Epoch: [ 0] [   31/  468] time: 7.5940, train_loss: 1.90945625, train_accuracy: 0.5078, test_Accuracy: 0.5779
# Epoch: [ 0] [   32/  468] time: 7.8027, train_loss: 1.84718299, train_accuracy: 0.6250, test_Accuracy: 0.5871
# Epoch: [ 0] [   33/  468] time: 8.0106, train_loss: 1.85687470, train_accuracy: 0.5938, test_Accuracy: 0.5831
# Epoch: [ 0] [   34/  468] time: 8.2082, train_loss: 1.81299889, train_accuracy: 0.6172, test_Accuracy: 0.5695
# Epoch: [ 0] [   35/  468] time: 8.4116, train_loss: 1.85694122, train_accuracy: 0.5391, test_Accuracy: 0.5675
# Epoch: [ 0] [   36/  468] time: 8.6096, train_loss: 1.85320711, train_accuracy: 0.5469, test_Accuracy: 0.5836
# Epoch: [ 0] [   37/  468] time: 8.8064, train_loss: 1.73707771, train_accuracy: 0.6484, test_Accuracy: 0.6120
# Epoch: [ 0] [   38/  468] time: 9.0038, train_loss: 1.74810505, train_accuracy: 0.6484, test_Accuracy: 0.6242
# Epoch: [ 0] [   39/  468] time: 9.2154, train_loss: 1.67255545, train_accuracy: 0.6094, test_Accuracy: 0.6012
# Epoch: [ 0] [   40/  468] time: 9.4217, train_loss: 1.68442917, train_accuracy: 0.5938, test_Accuracy: 0.5756
# Epoch: [ 0] [   41/  468] time: 9.6181, train_loss: 1.62127006, train_accuracy: 0.6016, test_Accuracy: 0.5621
# Epoch: [ 0] [   42/  468] time: 9.8269, train_loss: 1.69939315, train_accuracy: 0.5312, test_Accuracy: 0.5592
# Epoch: [ 0] [   43/  468] time: 10.0377, train_loss: 1.57460690, train_accuracy: 0.6250, test_Accuracy: 0.5604
# Epoch: [ 0] [   44/  468] time: 10.2381, train_loss: 1.59851956, train_accuracy: 0.5625, test_Accuracy: 0.5670
# Epoch: [ 0] [   45/  468] time: 10.4442, train_loss: 1.62543094, train_accuracy: 0.5000, test_Accuracy: 0.5882
# Epoch: [ 0] [   46/  468] time: 10.6517, train_loss: 1.60560489, train_accuracy: 0.5156, test_Accuracy: 0.6203
# Epoch: [ 0] [   47/  468] time: 10.8592, train_loss: 1.59155989, train_accuracy: 0.5625, test_Accuracy: 0.6554
# Epoch: [ 0] [   48/  468] time: 11.0887, train_loss: 1.52882361, train_accuracy: 0.6250, test_Accuracy: 0.6866
# Epoch: [ 0] [   49/  468] time: 11.3131, train_loss: 1.42849207, train_accuracy: 0.7266, test_Accuracy: 0.7051
# Epoch: [ 0] [   50/  468] time: 11.5132, train_loss: 1.48136544, train_accuracy: 0.6719, test_Accuracy: 0.7163
# Epoch: [ 0] [   51/  468] time: 11.7179, train_loss: 1.28378534, train_accuracy: 0.7969, test_Accuracy: 0.7130
# Epoch: [ 0] [   52/  468] time: 11.9283, train_loss: 1.45506060, train_accuracy: 0.6484, test_Accuracy: 0.7142
# Epoch: [ 0] [   53/  468] time: 12.1307, train_loss: 1.36461997, train_accuracy: 0.7578, test_Accuracy: 0.7160
# Epoch: [ 0] [   54/  468] time: 12.3387, train_loss: 1.34176481, train_accuracy: 0.7109, test_Accuracy: 0.7178
# Epoch: [ 0] [   55/  468] time: 12.5402, train_loss: 1.34100747, train_accuracy: 0.7422, test_Accuracy: 0.7214
# Epoch: [ 0] [   56/  468] time: 12.7493, train_loss: 1.26513958, train_accuracy: 0.7656, test_Accuracy: 0.7253
# Epoch: [ 0] [   57/  468] time: 12.9449, train_loss: 1.28496182, train_accuracy: 0.7422, test_Accuracy: 0.7299
# Epoch: [ 0] [   58/  468] time: 13.1455, train_loss: 1.20791698, train_accuracy: 0.7500, test_Accuracy: 0.7307
# Epoch: [ 0] [   59/  468] time: 13.3545, train_loss: 1.25504446, train_accuracy: 0.7109, test_Accuracy: 0.7351
# Epoch: [ 0] [   60/  468] time: 13.5654, train_loss: 1.19042635, train_accuracy: 0.7734, test_Accuracy: 0.7403
# Epoch: [ 0] [   61/  468] time: 13.7680, train_loss: 1.24428594, train_accuracy: 0.6797, test_Accuracy: 0.7403
# Epoch: [ 0] [   62/  468] time: 13.9655, train_loss: 1.21355987, train_accuracy: 0.7109, test_Accuracy: 0.7443
# Epoch: [ 0] [   63/  468] time: 14.1688, train_loss: 1.20191920, train_accuracy: 0.6797, test_Accuracy: 0.7467
# Epoch: [ 0] [   64/  468] time: 14.3921, train_loss: 1.12742305, train_accuracy: 0.7812, test_Accuracy: 0.7449
# Epoch: [ 0] [   65/  468] time: 14.6009, train_loss: 1.08387017, train_accuracy: 0.7734, test_Accuracy: 0.7427
# Epoch: [ 0] [   66/  468] time: 14.8016, train_loss: 1.18111300, train_accuracy: 0.6953, test_Accuracy: 0.7442
# Epoch: [ 0] [   67/  468] time: 15.0155, train_loss: 1.14215529, train_accuracy: 0.7734, test_Accuracy: 0.7524
# Epoch: [ 0] [   68/  468] time: 15.2247, train_loss: 0.99384379, train_accuracy: 0.7969, test_Accuracy: 0.7581
# Epoch: [ 0] [   69/  468] time: 15.4388, train_loss: 1.04671812, train_accuracy: 0.7656, test_Accuracy: 0.7645
# Epoch: [ 0] [   70/  468] time: 15.6480, train_loss: 1.14284420, train_accuracy: 0.7031, test_Accuracy: 0.7762
# Epoch: [ 0] [   71/  468] time: 15.8480, train_loss: 0.98947328, train_accuracy: 0.7969, test_Accuracy: 0.7850
# Epoch: [ 0] [   72/  468] time: 16.0530, train_loss: 0.96340108, train_accuracy: 0.7891, test_Accuracy: 0.7871
# Epoch: [ 0] [   73/  468] time: 16.2617, train_loss: 0.92762750, train_accuracy: 0.8516, test_Accuracy: 0.7836
# Epoch: [ 0] [   74/  468] time: 16.4753, train_loss: 0.98822808, train_accuracy: 0.7969, test_Accuracy: 0.7767
# Epoch: [ 0] [   75/  468] time: 16.6724, train_loss: 1.06382275, train_accuracy: 0.7578, test_Accuracy: 0.7761
# Epoch: [ 0] [   76/  468] time: 16.8754, train_loss: 0.90995270, train_accuracy: 0.8438, test_Accuracy: 0.7719
# Epoch: [ 0] [   77/  468] time: 17.0813, train_loss: 0.84568572, train_accuracy: 0.8438, test_Accuracy: 0.7663
# Epoch: [ 0] [   78/  468] time: 17.2874, train_loss: 0.95936811, train_accuracy: 0.7266, test_Accuracy: 0.7682
# Epoch: [ 0] [   79/  468] time: 17.4881, train_loss: 1.01906312, train_accuracy: 0.7578, test_Accuracy: 0.7678
# Epoch: [ 0] [   80/  468] time: 17.6951, train_loss: 0.98169798, train_accuracy: 0.6953, test_Accuracy: 0.7742
# Epoch: [ 0] [   81/  468] time: 17.8959, train_loss: 0.93358052, train_accuracy: 0.7656, test_Accuracy: 0.7870
# Epoch: [ 0] [   82/  468] time: 18.1098, train_loss: 0.94159108, train_accuracy: 0.7891, test_Accuracy: 0.8032
# Epoch: [ 0] [   83/  468] time: 18.3173, train_loss: 0.92487818, train_accuracy: 0.7734, test_Accuracy: 0.8097
# Epoch: [ 0] [   84/  468] time: 18.5301, train_loss: 0.87372881, train_accuracy: 0.8594, test_Accuracy: 0.8128
# Epoch: [ 0] [   85/  468] time: 18.7415, train_loss: 0.85044122, train_accuracy: 0.7969, test_Accuracy: 0.8141
# Epoch: [ 0] [   86/  468] time: 18.9519, train_loss: 0.83579350, train_accuracy: 0.8125, test_Accuracy: 0.8144
# Epoch: [ 0] [   87/  468] time: 19.1789, train_loss: 0.82619447, train_accuracy: 0.8125, test_Accuracy: 0.8151
# Epoch: [ 0] [   88/  468] time: 19.3896, train_loss: 0.79955029, train_accuracy: 0.7969, test_Accuracy: 0.8172
# Epoch: [ 0] [   89/  468] time: 19.5876, train_loss: 0.84811080, train_accuracy: 0.7891, test_Accuracy: 0.8216
# Epoch: [ 0] [   90/  468] time: 19.7948, train_loss: 0.84393418, train_accuracy: 0.7969, test_Accuracy: 0.8246
# Epoch: [ 0] [   91/  468] time: 19.9933, train_loss: 0.83508432, train_accuracy: 0.8047, test_Accuracy: 0.8242
# Epoch: [ 0] [   92/  468] time: 20.2008, train_loss: 0.83926725, train_accuracy: 0.7578, test_Accuracy: 0.8239
# Epoch: [ 0] [   93/  468] time: 20.3958, train_loss: 0.85404527, train_accuracy: 0.7656, test_Accuracy: 0.8215
# Epoch: [ 0] [   94/  468] time: 20.6063, train_loss: 0.72287768, train_accuracy: 0.8203, test_Accuracy: 0.8240
# Epoch: [ 0] [   95/  468] time: 20.8067, train_loss: 0.83557636, train_accuracy: 0.7500, test_Accuracy: 0.8252
# Epoch: [ 0] [   96/  468] time: 21.0123, train_loss: 0.80112308, train_accuracy: 0.8438, test_Accuracy: 0.8278
# Epoch: [ 0] [   97/  468] time: 21.2188, train_loss: 0.81035125, train_accuracy: 0.8281, test_Accuracy: 0.8320
# Epoch: [ 0] [   98/  468] time: 21.4427, train_loss: 0.67714989, train_accuracy: 0.8672, test_Accuracy: 0.8353
# Epoch: [ 0] [   99/  468] time: 21.6411, train_loss: 0.69848955, train_accuracy: 0.8906, test_Accuracy: 0.8388
# Epoch: [ 0] [  100/  468] time: 21.8433, train_loss: 0.63285339, train_accuracy: 0.8906, test_Accuracy: 0.8413
# Epoch: [ 0] [  101/  468] time: 22.0426, train_loss: 0.67820394, train_accuracy: 0.8516, test_Accuracy: 0.8421
# Epoch: [ 0] [  102/  468] time: 22.2475, train_loss: 0.71125710, train_accuracy: 0.8594, test_Accuracy: 0.8432
# Epoch: [ 0] [  103/  468] time: 22.4586, train_loss: 0.75626063, train_accuracy: 0.8047, test_Accuracy: 0.8450
# Epoch: [ 0] [  104/  468] time: 22.6516, train_loss: 0.70663059, train_accuracy: 0.8281, test_Accuracy: 0.8446
# Epoch: [ 0] [  105/  468] time: 22.8501, train_loss: 0.60331053, train_accuracy: 0.8906, test_Accuracy: 0.8440
# Epoch: [ 0] [  106/  468] time: 23.0487, train_loss: 0.70344752, train_accuracy: 0.7969, test_Accuracy: 0.8425
# Epoch: [ 0] [  107/  468] time: 23.2511, train_loss: 0.68980443, train_accuracy: 0.8359, test_Accuracy: 0.8417
# Epoch: [ 0] [  108/  468] time: 23.4579, train_loss: 0.64240313, train_accuracy: 0.8516, test_Accuracy: 0.8383
# Epoch: [ 0] [  109/  468] time: 23.6789, train_loss: 0.69661301, train_accuracy: 0.8203, test_Accuracy: 0.8388
# Epoch: [ 0] [  110/  468] time: 23.8896, train_loss: 0.59153897, train_accuracy: 0.8281, test_Accuracy: 0.8422
# Epoch: [ 0] [  111/  468] time: 24.0930, train_loss: 0.64192253, train_accuracy: 0.8438, test_Accuracy: 0.8465
# Epoch: [ 0] [  112/  468] time: 24.2999, train_loss: 0.68382668, train_accuracy: 0.8516, test_Accuracy: 0.8476
# Epoch: [ 0] [  113/  468] time: 24.4996, train_loss: 0.67421174, train_accuracy: 0.8125, test_Accuracy: 0.8511
# Epoch: [ 0] [  114/  468] time: 24.7016, train_loss: 0.58305323, train_accuracy: 0.8828, test_Accuracy: 0.8526
# Epoch: [ 0] [  115/  468] time: 24.9051, train_loss: 0.56436777, train_accuracy: 0.9062, test_Accuracy: 0.8529
# Epoch: [ 0] [  116/  468] time: 25.1094, train_loss: 0.58138371, train_accuracy: 0.8672, test_Accuracy: 0.8533
# Epoch: [ 0] [  117/  468] time: 25.3146, train_loss: 0.67690682, train_accuracy: 0.8438, test_Accuracy: 0.8550
# Epoch: [ 0] [  118/  468] time: 25.5272, train_loss: 0.50901479, train_accuracy: 0.9141, test_Accuracy: 0.8573
# Epoch: [ 0] [  119/  468] time: 25.7345, train_loss: 0.58230048, train_accuracy: 0.8359, test_Accuracy: 0.8554
# Epoch: [ 0] [  120/  468] time: 25.9311, train_loss: 0.68675959, train_accuracy: 0.8125, test_Accuracy: 0.8575
# Epoch: [ 0] [  121/  468] time: 26.1405, train_loss: 0.71928161, train_accuracy: 0.7812, test_Accuracy: 0.8571
# Epoch: [ 0] [  122/  468] time: 26.3552, train_loss: 0.63822281, train_accuracy: 0.8516, test_Accuracy: 0.8542
# Epoch: [ 0] [  123/  468] time: 26.5676, train_loss: 0.60954672, train_accuracy: 0.8281, test_Accuracy: 0.8537
# Epoch: [ 0] [  124/  468] time: 26.7619, train_loss: 0.57336676, train_accuracy: 0.8672, test_Accuracy: 0.8536
# Epoch: [ 0] [  125/  468] time: 26.9623, train_loss: 0.52974051, train_accuracy: 0.8984, test_Accuracy: 0.8530
# Epoch: [ 0] [  126/  468] time: 27.1571, train_loss: 0.65562630, train_accuracy: 0.8359, test_Accuracy: 0.8523
# Epoch: [ 0] [  127/  468] time: 27.3655, train_loss: 0.55345011, train_accuracy: 0.8828, test_Accuracy: 0.8520
# Epoch: [ 0] [  128/  468] time: 27.5657, train_loss: 0.61348009, train_accuracy: 0.7812, test_Accuracy: 0.8545
# Epoch: [ 0] [  129/  468] time: 27.7695, train_loss: 0.56562018, train_accuracy: 0.8438, test_Accuracy: 0.8575
# Epoch: [ 0] [  130/  468] time: 27.9660, train_loss: 0.51437944, train_accuracy: 0.8594, test_Accuracy: 0.8602
# Epoch: [ 0] [  131/  468] time: 28.1673, train_loss: 0.45166737, train_accuracy: 0.9062, test_Accuracy: 0.8612
# Epoch: [ 0] [  132/  468] time: 28.3753, train_loss: 0.49440005, train_accuracy: 0.8828, test_Accuracy: 0.8640
# Epoch: [ 0] [  133/  468] time: 28.5827, train_loss: 0.54091120, train_accuracy: 0.8516, test_Accuracy: 0.8656
# Epoch: [ 0] [  134/  468] time: 28.7823, train_loss: 0.56983602, train_accuracy: 0.8516, test_Accuracy: 0.8674
# Epoch: [ 0] [  135/  468] time: 28.9831, train_loss: 0.53875190, train_accuracy: 0.8828, test_Accuracy: 0.8674
# Epoch: [ 0] [  136/  468] time: 29.1823, train_loss: 0.58587933, train_accuracy: 0.8594, test_Accuracy: 0.8664
# Epoch: [ 0] [  137/  468] time: 29.3885, train_loss: 0.55440146, train_accuracy: 0.8516, test_Accuracy: 0.8655
# Epoch: [ 0] [  138/  468] time: 29.5952, train_loss: 0.63291270, train_accuracy: 0.8359, test_Accuracy: 0.8648
# Epoch: [ 0] [  139/  468] time: 29.8011, train_loss: 0.52799624, train_accuracy: 0.8516, test_Accuracy: 0.8627
# Epoch: [ 0] [  140/  468] time: 30.0018, train_loss: 0.56199598, train_accuracy: 0.8516, test_Accuracy: 0.8642
# Epoch: [ 0] [  141/  468] time: 30.2141, train_loss: 0.53784490, train_accuracy: 0.8594, test_Accuracy: 0.8670
# Epoch: [ 0] [  142/  468] time: 30.4258, train_loss: 0.57675850, train_accuracy: 0.8516, test_Accuracy: 0.8702
# Epoch: [ 0] [  143/  468] time: 30.6358, train_loss: 0.48165479, train_accuracy: 0.8984, test_Accuracy: 0.8710
# Epoch: [ 0] [  144/  468] time: 30.8382, train_loss: 0.52231801, train_accuracy: 0.8750, test_Accuracy: 0.8734
# Epoch: [ 0] [  145/  468] time: 31.0440, train_loss: 0.44366160, train_accuracy: 0.9141, test_Accuracy: 0.8751
# Epoch: [ 0] [  146/  468] time: 31.2568, train_loss: 0.44144866, train_accuracy: 0.8828, test_Accuracy: 0.8738
# Epoch: [ 0] [  147/  468] time: 31.4730, train_loss: 0.53455877, train_accuracy: 0.8594, test_Accuracy: 0.8722
# Epoch: [ 0] [  148/  468] time: 31.6652, train_loss: 0.43933412, train_accuracy: 0.8906, test_Accuracy: 0.8714
# Epoch: [ 0] [  149/  468] time: 31.8791, train_loss: 0.41510099, train_accuracy: 0.8984, test_Accuracy: 0.8705
# Epoch: [ 0] [  150/  468] time: 32.0937, train_loss: 0.54079378, train_accuracy: 0.8359, test_Accuracy: 0.8697
# Epoch: [ 0] [  151/  468] time: 32.3036, train_loss: 0.51585037, train_accuracy: 0.8828, test_Accuracy: 0.8710
# Epoch: [ 0] [  152/  468] time: 32.5056, train_loss: 0.46587920, train_accuracy: 0.8750, test_Accuracy: 0.8717
# Epoch: [ 0] [  153/  468] time: 32.7154, train_loss: 0.48187965, train_accuracy: 0.8750, test_Accuracy: 0.8727
# Epoch: [ 0] [  154/  468] time: 32.9238, train_loss: 0.44957867, train_accuracy: 0.8984, test_Accuracy: 0.8749
# Epoch: [ 0] [  155/  468] time: 33.1311, train_loss: 0.47631395, train_accuracy: 0.8828, test_Accuracy: 0.8792
# Epoch: [ 0] [  156/  468] time: 33.3355, train_loss: 0.43676800, train_accuracy: 0.8750, test_Accuracy: 0.8810
# Epoch: [ 0] [  157/  468] time: 33.5504, train_loss: 0.43698096, train_accuracy: 0.9141, test_Accuracy: 0.8839
# Epoch: [ 0] [  158/  468] time: 33.7716, train_loss: 0.43666396, train_accuracy: 0.8750, test_Accuracy: 0.8826
# Epoch: [ 0] [  159/  468] time: 33.9687, train_loss: 0.49322438, train_accuracy: 0.8828, test_Accuracy: 0.8809
# Epoch: [ 0] [  160/  468] time: 34.1728, train_loss: 0.42170155, train_accuracy: 0.8906, test_Accuracy: 0.8806
# Epoch: [ 0] [  161/  468] time: 34.3846, train_loss: 0.57747358, train_accuracy: 0.8125, test_Accuracy: 0.8823
# Epoch: [ 0] [  162/  468] time: 34.5852, train_loss: 0.39495847, train_accuracy: 0.9141, test_Accuracy: 0.8839
# Epoch: [ 0] [  163/  468] time: 34.7923, train_loss: 0.41639215, train_accuracy: 0.9062, test_Accuracy: 0.8843
# Epoch: [ 0] [  164/  468] time: 34.9827, train_loss: 0.41128230, train_accuracy: 0.8906, test_Accuracy: 0.8843
# Epoch: [ 0] [  165/  468] time: 35.1769, train_loss: 0.41200322, train_accuracy: 0.8984, test_Accuracy: 0.8857
# Epoch: [ 0] [  166/  468] time: 35.3660, train_loss: 0.46384877, train_accuracy: 0.8672, test_Accuracy: 0.8855
# Epoch: [ 0] [  167/  468] time: 35.5704, train_loss: 0.50497085, train_accuracy: 0.8750, test_Accuracy: 0.8876
# Epoch: [ 0] [  168/  468] time: 35.7848, train_loss: 0.53685033, train_accuracy: 0.8516, test_Accuracy: 0.8881
# Epoch: [ 0] [  169/  468] time: 35.9932, train_loss: 0.45458907, train_accuracy: 0.8906, test_Accuracy: 0.8880
# Epoch: [ 0] [  170/  468] time: 36.1985, train_loss: 0.45459521, train_accuracy: 0.8984, test_Accuracy: 0.8878
# Epoch: [ 0] [  171/  468] time: 36.4101, train_loss: 0.49431753, train_accuracy: 0.8672, test_Accuracy: 0.8873
# Epoch: [ 0] [  172/  468] time: 36.6059, train_loss: 0.37807623, train_accuracy: 0.9062, test_Accuracy: 0.8875
# Epoch: [ 0] [  173/  468] time: 36.8153, train_loss: 0.51286411, train_accuracy: 0.8828, test_Accuracy: 0.8891
# Epoch: [ 0] [  174/  468] time: 37.0291, train_loss: 0.54008085, train_accuracy: 0.8516, test_Accuracy: 0.8895
# Epoch: [ 0] [  175/  468] time: 37.2376, train_loss: 0.48398238, train_accuracy: 0.8594, test_Accuracy: 0.8899
# Epoch: [ 0] [  176/  468] time: 37.4402, train_loss: 0.60347748, train_accuracy: 0.8516, test_Accuracy: 0.8908
# Epoch: [ 0] [  177/  468] time: 37.6399, train_loss: 0.33938920, train_accuracy: 0.9141, test_Accuracy: 0.8914
# Epoch: [ 0] [  178/  468] time: 37.8637, train_loss: 0.49980175, train_accuracy: 0.8438, test_Accuracy: 0.8926
# Epoch: [ 0] [  179/  468] time: 38.0787, train_loss: 0.40354005, train_accuracy: 0.8906, test_Accuracy: 0.8919
# Epoch: [ 0] [  180/  468] time: 38.2829, train_loss: 0.44964123, train_accuracy: 0.9062, test_Accuracy: 0.8924
# Epoch: [ 0] [  181/  468] time: 38.4941, train_loss: 0.48033616, train_accuracy: 0.8984, test_Accuracy: 0.8925
# Epoch: [ 0] [  182/  468] time: 38.6973, train_loss: 0.43241817, train_accuracy: 0.8672, test_Accuracy: 0.8926
# Epoch: [ 0] [  183/  468] time: 38.9106, train_loss: 0.39370614, train_accuracy: 0.8750, test_Accuracy: 0.8935
# Epoch: [ 0] [  184/  468] time: 39.1237, train_loss: 0.38597459, train_accuracy: 0.9141, test_Accuracy: 0.8946
# Epoch: [ 0] [  185/  468] time: 39.3392, train_loss: 0.43455115, train_accuracy: 0.8594, test_Accuracy: 0.8953
# Epoch: [ 0] [  186/  468] time: 39.5604, train_loss: 0.35337937, train_accuracy: 0.9219, test_Accuracy: 0.8964
# Epoch: [ 0] [  187/  468] time: 39.7705, train_loss: 0.43956679, train_accuracy: 0.8984, test_Accuracy: 0.8967
# Epoch: [ 0] [  188/  468] time: 39.9795, train_loss: 0.47002667, train_accuracy: 0.8984, test_Accuracy: 0.8962
# Epoch: [ 0] [  189/  468] time: 40.2012, train_loss: 0.44193655, train_accuracy: 0.8906, test_Accuracy: 0.8964
# Epoch: [ 0] [  190/  468] time: 40.4090, train_loss: 0.39817232, train_accuracy: 0.8672, test_Accuracy: 0.8962
# Epoch: [ 0] [  191/  468] time: 40.6249, train_loss: 0.36302361, train_accuracy: 0.8984, test_Accuracy: 0.8966
# Epoch: [ 0] [  192/  468] time: 40.8378, train_loss: 0.41904420, train_accuracy: 0.8984, test_Accuracy: 0.8962
# Epoch: [ 0] [  193/  468] time: 41.0386, train_loss: 0.35789376, train_accuracy: 0.8984, test_Accuracy: 0.8957
# Epoch: [ 0] [  194/  468] time: 41.2529, train_loss: 0.42455018, train_accuracy: 0.8906, test_Accuracy: 0.8955
# Epoch: [ 0] [  195/  468] time: 41.4606, train_loss: 0.47517040, train_accuracy: 0.8359, test_Accuracy: 0.8965
# Epoch: [ 0] [  196/  468] time: 41.6599, train_loss: 0.33004081, train_accuracy: 0.9375, test_Accuracy: 0.8966
# Epoch: [ 0] [  197/  468] time: 41.8715, train_loss: 0.33359963, train_accuracy: 0.9141, test_Accuracy: 0.8961
# Epoch: [ 0] [  198/  468] time: 42.0910, train_loss: 0.40731427, train_accuracy: 0.8906, test_Accuracy: 0.8954
# Epoch: [ 0] [  199/  468] time: 42.3099, train_loss: 0.41809511, train_accuracy: 0.8750, test_Accuracy: 0.8962
# Epoch: [ 0] [  200/  468] time: 42.5219, train_loss: 0.47022372, train_accuracy: 0.8828, test_Accuracy: 0.8950
# Epoch: [ 0] [  201/  468] time: 42.7168, train_loss: 0.34400320, train_accuracy: 0.9531, test_Accuracy: 0.8961
# Epoch: [ 0] [  202/  468] time: 42.9289, train_loss: 0.39023831, train_accuracy: 0.8828, test_Accuracy: 0.8952
# Epoch: [ 0] [  203/  468] time: 43.1408, train_loss: 0.41975820, train_accuracy: 0.9141, test_Accuracy: 0.8961
# Epoch: [ 0] [  204/  468] time: 43.3454, train_loss: 0.39904732, train_accuracy: 0.9062, test_Accuracy: 0.8968
# Epoch: [ 0] [  205/  468] time: 43.5601, train_loss: 0.40315545, train_accuracy: 0.8672, test_Accuracy: 0.8986
# Epoch: [ 0] [  206/  468] time: 43.7765, train_loss: 0.31490847, train_accuracy: 0.9062, test_Accuracy: 0.8988
# Epoch: [ 0] [  207/  468] time: 43.9801, train_loss: 0.33632314, train_accuracy: 0.9141, test_Accuracy: 0.8982
# Epoch: [ 0] [  208/  468] time: 44.1807, train_loss: 0.31153661, train_accuracy: 0.9297, test_Accuracy: 0.8991
# Epoch: [ 0] [  209/  468] time: 44.3934, train_loss: 0.38714501, train_accuracy: 0.8828, test_Accuracy: 0.8994
# Epoch: [ 0] [  210/  468] time: 44.5935, train_loss: 0.35083428, train_accuracy: 0.9297, test_Accuracy: 0.9002
# Epoch: [ 0] [  211/  468] time: 44.8065, train_loss: 0.39621252, train_accuracy: 0.9297, test_Accuracy: 0.9009
# Epoch: [ 0] [  212/  468] time: 45.0060, train_loss: 0.46405548, train_accuracy: 0.8672, test_Accuracy: 0.9019
# Epoch: [ 0] [  213/  468] time: 45.2235, train_loss: 0.36191183, train_accuracy: 0.8906, test_Accuracy: 0.9025
# Epoch: [ 0] [  214/  468] time: 45.4323, train_loss: 0.34973460, train_accuracy: 0.9219, test_Accuracy: 0.9019
# Epoch: [ 0] [  215/  468] time: 45.6461, train_loss: 0.39880663, train_accuracy: 0.9141, test_Accuracy: 0.9017
# Epoch: [ 0] [  216/  468] time: 45.8611, train_loss: 0.39405617, train_accuracy: 0.8906, test_Accuracy: 0.9016
# Epoch: [ 0] [  217/  468] time: 46.0760, train_loss: 0.48485100, train_accuracy: 0.8750, test_Accuracy: 0.9007
# Epoch: [ 0] [  218/  468] time: 46.2737, train_loss: 0.36704797, train_accuracy: 0.9062, test_Accuracy: 0.8998
# Epoch: [ 0] [  219/  468] time: 46.4836, train_loss: 0.34143776, train_accuracy: 0.8906, test_Accuracy: 0.8988
# Epoch: [ 0] [  220/  468] time: 46.6966, train_loss: 0.47794765, train_accuracy: 0.8438, test_Accuracy: 0.8991
# Epoch: [ 0] [  221/  468] time: 46.9070, train_loss: 0.28099158, train_accuracy: 0.9375, test_Accuracy: 0.9000
# Epoch: [ 0] [  222/  468] time: 47.1125, train_loss: 0.41229361, train_accuracy: 0.9219, test_Accuracy: 0.9011
# Epoch: [ 0] [  223/  468] time: 47.3358, train_loss: 0.40237334, train_accuracy: 0.8906, test_Accuracy: 0.9026
# Epoch: [ 0] [  224/  468] time: 47.5347, train_loss: 0.39957309, train_accuracy: 0.8906, test_Accuracy: 0.9024
# Epoch: [ 0] [  225/  468] time: 47.7496, train_loss: 0.45674926, train_accuracy: 0.8516, test_Accuracy: 0.9019
# Epoch: [ 0] [  226/  468] time: 47.9596, train_loss: 0.43965709, train_accuracy: 0.8672, test_Accuracy: 0.9014
# Epoch: [ 0] [  227/  468] time: 48.1740, train_loss: 0.27601299, train_accuracy: 0.9375, test_Accuracy: 0.9018
# Epoch: [ 0] [  228/  468] time: 48.3832, train_loss: 0.45672250, train_accuracy: 0.8828, test_Accuracy: 0.9019
# Epoch: [ 0] [  229/  468] time: 48.5972, train_loss: 0.37041157, train_accuracy: 0.9141, test_Accuracy: 0.9017
# Epoch: [ 0] [  230/  468] time: 48.8001, train_loss: 0.23999946, train_accuracy: 0.9531, test_Accuracy: 0.8999
# Epoch: [ 0] [  231/  468] time: 49.0233, train_loss: 0.24453253, train_accuracy: 0.9609, test_Accuracy: 0.8989
# Epoch: [ 0] [  232/  468] time: 49.2302, train_loss: 0.40624276, train_accuracy: 0.8984, test_Accuracy: 0.8985
# Epoch: [ 0] [  233/  468] time: 49.4432, train_loss: 0.42667079, train_accuracy: 0.8672, test_Accuracy: 0.8990
# Epoch: [ 0] [  234/  468] time: 49.6398, train_loss: 0.34041673, train_accuracy: 0.9141, test_Accuracy: 0.8996
# Epoch: [ 0] [  235/  468] time: 49.8566, train_loss: 0.47580588, train_accuracy: 0.8516, test_Accuracy: 0.9015
# Epoch: [ 0] [  236/  468] time: 50.0580, train_loss: 0.40909502, train_accuracy: 0.8906, test_Accuracy: 0.9029
# Epoch: [ 0] [  237/  468] time: 50.2664, train_loss: 0.33702242, train_accuracy: 0.9062, test_Accuracy: 0.9031
# Epoch: [ 0] [  238/  468] time: 50.4629, train_loss: 0.41862780, train_accuracy: 0.8828, test_Accuracy: 0.9045
# Epoch: [ 0] [  239/  468] time: 50.6625, train_loss: 0.38386512, train_accuracy: 0.9141, test_Accuracy: 0.9050
# Epoch: [ 0] [  240/  468] time: 50.8625, train_loss: 0.39112774, train_accuracy: 0.8750, test_Accuracy: 0.9049
# Epoch: [ 0] [  241/  468] time: 51.0654, train_loss: 0.31475943, train_accuracy: 0.8906, test_Accuracy: 0.9047
# Epoch: [ 0] [  242/  468] time: 51.2680, train_loss: 0.31223688, train_accuracy: 0.9141, test_Accuracy: 0.9057
# Epoch: [ 0] [  243/  468] time: 51.4942, train_loss: 0.34606117, train_accuracy: 0.8906, test_Accuracy: 0.9044
# Epoch: [ 0] [  244/  468] time: 51.6905, train_loss: 0.37602374, train_accuracy: 0.8672, test_Accuracy: 0.9047
# Epoch: [ 0] [  245/  468] time: 51.9099, train_loss: 0.32770580, train_accuracy: 0.8984, test_Accuracy: 0.9050
# Epoch: [ 0] [  246/  468] time: 52.1156, train_loss: 0.30412430, train_accuracy: 0.9297, test_Accuracy: 0.9045
# Epoch: [ 0] [  247/  468] time: 52.3145, train_loss: 0.25709757, train_accuracy: 0.9375, test_Accuracy: 0.9053
# Epoch: [ 0] [  248/  468] time: 52.5144, train_loss: 0.38646972, train_accuracy: 0.8984, test_Accuracy: 0.9051
# Epoch: [ 0] [  249/  468] time: 52.7125, train_loss: 0.22413331, train_accuracy: 0.9531, test_Accuracy: 0.9046
# Epoch: [ 0] [  250/  468] time: 52.9152, train_loss: 0.33234257, train_accuracy: 0.9062, test_Accuracy: 0.9039
# Epoch: [ 0] [  251/  468] time: 53.1150, train_loss: 0.30082107, train_accuracy: 0.9375, test_Accuracy: 0.9043
# Epoch: [ 0] [  252/  468] time: 53.3174, train_loss: 0.36246213, train_accuracy: 0.8906, test_Accuracy: 0.9049
# Epoch: [ 0] [  253/  468] time: 53.5341, train_loss: 0.26902643, train_accuracy: 0.9375, test_Accuracy: 0.9059
# Epoch: [ 0] [  254/  468] time: 53.7491, train_loss: 0.32371581, train_accuracy: 0.9062, test_Accuracy: 0.9062
# Epoch: [ 0] [  255/  468] time: 53.9606, train_loss: 0.27510077, train_accuracy: 0.9375, test_Accuracy: 0.9067
# Epoch: [ 0] [  256/  468] time: 54.1521, train_loss: 0.34414777, train_accuracy: 0.8906, test_Accuracy: 0.9064
# Epoch: [ 0] [  257/  468] time: 54.3560, train_loss: 0.34877294, train_accuracy: 0.9219, test_Accuracy: 0.9064
# Epoch: [ 0] [  258/  468] time: 54.5480, train_loss: 0.36100629, train_accuracy: 0.8828, test_Accuracy: 0.9058
# Epoch: [ 0] [  259/  468] time: 54.7556, train_loss: 0.29291576, train_accuracy: 0.9141, test_Accuracy: 0.9052
# Epoch: [ 0] [  260/  468] time: 54.9611, train_loss: 0.30984789, train_accuracy: 0.8828, test_Accuracy: 0.9054
# Epoch: [ 0] [  261/  468] time: 55.1612, train_loss: 0.40110400, train_accuracy: 0.8438, test_Accuracy: 0.9062
# Epoch: [ 0] [  262/  468] time: 55.3682, train_loss: 0.37258917, train_accuracy: 0.9062, test_Accuracy: 0.9090
# Epoch: [ 0] [  263/  468] time: 55.5795, train_loss: 0.22074261, train_accuracy: 0.9453, test_Accuracy: 0.9092
# Epoch: [ 0] [  264/  468] time: 55.7825, train_loss: 0.26443478, train_accuracy: 0.9453, test_Accuracy: 0.9085
# Epoch: [ 0] [  265/  468] time: 55.9810, train_loss: 0.30444521, train_accuracy: 0.9141, test_Accuracy: 0.9085
# Epoch: [ 0] [  266/  468] time: 56.1817, train_loss: 0.38787648, train_accuracy: 0.9141, test_Accuracy: 0.9100
# Epoch: [ 0] [  267/  468] time: 56.3786, train_loss: 0.32639939, train_accuracy: 0.9141, test_Accuracy: 0.9087
# Epoch: [ 0] [  268/  468] time: 56.5881, train_loss: 0.19916521, train_accuracy: 0.9453, test_Accuracy: 0.9086
# Epoch: [ 0] [  269/  468] time: 56.7855, train_loss: 0.30853075, train_accuracy: 0.9375, test_Accuracy: 0.9085
# Epoch: [ 0] [  270/  468] time: 56.9868, train_loss: 0.27931485, train_accuracy: 0.9297, test_Accuracy: 0.9068
# Epoch: [ 0] [  271/  468] time: 57.1841, train_loss: 0.34437823, train_accuracy: 0.8984, test_Accuracy: 0.9070
# Epoch: [ 0] [  272/  468] time: 57.3892, train_loss: 0.31900534, train_accuracy: 0.9141, test_Accuracy: 0.9078
# Epoch: [ 0] [  273/  468] time: 57.5867, train_loss: 0.35619709, train_accuracy: 0.8828, test_Accuracy: 0.9080
# Epoch: [ 0] [  274/  468] time: 57.7855, train_loss: 0.26114902, train_accuracy: 0.9141, test_Accuracy: 0.9085
# Epoch: [ 0] [  275/  468] time: 57.9952, train_loss: 0.25724435, train_accuracy: 0.9375, test_Accuracy: 0.9094
# Epoch: [ 0] [  276/  468] time: 58.1943, train_loss: 0.18271092, train_accuracy: 0.9531, test_Accuracy: 0.9096
# Epoch: [ 0] [  277/  468] time: 58.3958, train_loss: 0.32172787, train_accuracy: 0.9219, test_Accuracy: 0.9107
# Epoch: [ 0] [  278/  468] time: 58.6061, train_loss: 0.25014424, train_accuracy: 0.9219, test_Accuracy: 0.9116
# Epoch: [ 0] [  279/  468] time: 58.7996, train_loss: 0.25471702, train_accuracy: 0.9141, test_Accuracy: 0.9119
# Epoch: [ 0] [  280/  468] time: 58.9982, train_loss: 0.20977587, train_accuracy: 0.9375, test_Accuracy: 0.9115
# Epoch: [ 0] [  281/  468] time: 59.1906, train_loss: 0.37695000, train_accuracy: 0.9141, test_Accuracy: 0.9117
# Epoch: [ 0] [  282/  468] time: 59.3982, train_loss: 0.39766210, train_accuracy: 0.8906, test_Accuracy: 0.9111
# Epoch: [ 0] [  283/  468] time: 59.5895, train_loss: 0.22848685, train_accuracy: 0.9531, test_Accuracy: 0.9098
# Epoch: [ 0] [  284/  468] time: 59.7872, train_loss: 0.31997520, train_accuracy: 0.9219, test_Accuracy: 0.9092
# Epoch: [ 0] [  285/  468] time: 59.9784, train_loss: 0.33261278, train_accuracy: 0.8984, test_Accuracy: 0.9095
# Epoch: [ 0] [  286/  468] time: 60.1879, train_loss: 0.31985304, train_accuracy: 0.8828, test_Accuracy: 0.9096
# Epoch: [ 0] [  287/  468] time: 60.3782, train_loss: 0.32517698, train_accuracy: 0.8906, test_Accuracy: 0.9112
# Epoch: [ 0] [  288/  468] time: 60.5776, train_loss: 0.40806693, train_accuracy: 0.8828, test_Accuracy: 0.9124
# Epoch: [ 0] [  289/  468] time: 60.7689, train_loss: 0.29499567, train_accuracy: 0.9062, test_Accuracy: 0.9128
# Epoch: [ 0] [  290/  468] time: 60.9670, train_loss: 0.35885644, train_accuracy: 0.8984, test_Accuracy: 0.9122
# Epoch: [ 0] [  291/  468] time: 61.1793, train_loss: 0.25705385, train_accuracy: 0.9453, test_Accuracy: 0.9116
# Epoch: [ 0] [  292/  468] time: 61.3757, train_loss: 0.34541267, train_accuracy: 0.8828, test_Accuracy: 0.9120
# Epoch: [ 0] [  293/  468] time: 61.5778, train_loss: 0.30756885, train_accuracy: 0.9062, test_Accuracy: 0.9126
# Epoch: [ 0] [  294/  468] time: 61.7812, train_loss: 0.19861910, train_accuracy: 0.9531, test_Accuracy: 0.9121
# Epoch: [ 0] [  295/  468] time: 61.9822, train_loss: 0.28558248, train_accuracy: 0.9141, test_Accuracy: 0.9121
# Epoch: [ 0] [  296/  468] time: 62.1884, train_loss: 0.23395067, train_accuracy: 0.9375, test_Accuracy: 0.9119
# Epoch: [ 0] [  297/  468] time: 62.3793, train_loss: 0.34600452, train_accuracy: 0.9375, test_Accuracy: 0.9117
# Epoch: [ 0] [  298/  468] time: 62.5881, train_loss: 0.28830183, train_accuracy: 0.9219, test_Accuracy: 0.9127
# Epoch: [ 0] [  299/  468] time: 62.7901, train_loss: 0.32886338, train_accuracy: 0.9141, test_Accuracy: 0.9124
# Epoch: [ 0] [  300/  468] time: 62.9925, train_loss: 0.44072527, train_accuracy: 0.8906, test_Accuracy: 0.9112
# Epoch: [ 0] [  301/  468] time: 63.2054, train_loss: 0.32609496, train_accuracy: 0.9219, test_Accuracy: 0.9107
# Epoch: [ 0] [  302/  468] time: 63.3935, train_loss: 0.26166952, train_accuracy: 0.9219, test_Accuracy: 0.9103
# Epoch: [ 0] [  303/  468] time: 63.6002, train_loss: 0.36094719, train_accuracy: 0.8828, test_Accuracy: 0.9092
# Epoch: [ 0] [  304/  468] time: 63.8080, train_loss: 0.41525868, train_accuracy: 0.9062, test_Accuracy: 0.9092
# Epoch: [ 0] [  305/  468] time: 64.0047, train_loss: 0.23739380, train_accuracy: 0.9375, test_Accuracy: 0.9095
# Epoch: [ 0] [  306/  468] time: 64.2157, train_loss: 0.31129012, train_accuracy: 0.9219, test_Accuracy: 0.9100
# Epoch: [ 0] [  307/  468] time: 64.4168, train_loss: 0.32864767, train_accuracy: 0.9219, test_Accuracy: 0.9111
# Epoch: [ 0] [  308/  468] time: 64.6161, train_loss: 0.26728630, train_accuracy: 0.9141, test_Accuracy: 0.9113
# Epoch: [ 0] [  309/  468] time: 64.8159, train_loss: 0.27429384, train_accuracy: 0.8984, test_Accuracy: 0.9121
# Epoch: [ 0] [  310/  468] time: 65.0048, train_loss: 0.34930384, train_accuracy: 0.8906, test_Accuracy: 0.9125
# Epoch: [ 0] [  311/  468] time: 65.2206, train_loss: 0.25190055, train_accuracy: 0.9375, test_Accuracy: 0.9136
# Epoch: [ 0] [  312/  468] time: 65.4133, train_loss: 0.29334265, train_accuracy: 0.9062, test_Accuracy: 0.9137
# Epoch: [ 0] [  313/  468] time: 65.6168, train_loss: 0.37954599, train_accuracy: 0.8828, test_Accuracy: 0.9136
# Epoch: [ 0] [  314/  468] time: 65.8102, train_loss: 0.36993554, train_accuracy: 0.8984, test_Accuracy: 0.9141
# Epoch: [ 0] [  315/  468] time: 66.0110, train_loss: 0.27259994, train_accuracy: 0.9219, test_Accuracy: 0.9135
# Epoch: [ 0] [  316/  468] time: 66.2140, train_loss: 0.37957510, train_accuracy: 0.8750, test_Accuracy: 0.9147
# Epoch: [ 0] [  317/  468] time: 66.4296, train_loss: 0.36863229, train_accuracy: 0.8906, test_Accuracy: 0.9163
# Epoch: [ 0] [  318/  468] time: 66.6296, train_loss: 0.24062979, train_accuracy: 0.9062, test_Accuracy: 0.9157
# Epoch: [ 0] [  319/  468] time: 66.8275, train_loss: 0.27550098, train_accuracy: 0.9297, test_Accuracy: 0.9157
# Epoch: [ 0] [  320/  468] time: 67.0333, train_loss: 0.35068178, train_accuracy: 0.8828, test_Accuracy: 0.9149
# Epoch: [ 0] [  321/  468] time: 67.2407, train_loss: 0.23667055, train_accuracy: 0.9375, test_Accuracy: 0.9143
# Epoch: [ 0] [  322/  468] time: 67.4345, train_loss: 0.28887844, train_accuracy: 0.9062, test_Accuracy: 0.9144
# Epoch: [ 0] [  323/  468] time: 67.6314, train_loss: 0.18747047, train_accuracy: 0.9453, test_Accuracy: 0.9151
# Epoch: [ 0] [  324/  468] time: 67.8304, train_loss: 0.40548661, train_accuracy: 0.8750, test_Accuracy: 0.9146
# Epoch: [ 0] [  325/  468] time: 68.0249, train_loss: 0.22143346, train_accuracy: 0.9219, test_Accuracy: 0.9139
# Epoch: [ 0] [  326/  468] time: 68.2372, train_loss: 0.30173105, train_accuracy: 0.9219, test_Accuracy: 0.9151
# Epoch: [ 0] [  327/  468] time: 68.4361, train_loss: 0.39582795, train_accuracy: 0.8828, test_Accuracy: 0.9151
# Epoch: [ 0] [  328/  468] time: 68.6333, train_loss: 0.23347598, train_accuracy: 0.9531, test_Accuracy: 0.9151
# Epoch: [ 0] [  329/  468] time: 68.8310, train_loss: 0.26054886, train_accuracy: 0.9062, test_Accuracy: 0.9149
# Epoch: [ 0] [  330/  468] time: 69.0237, train_loss: 0.24035424, train_accuracy: 0.9297, test_Accuracy: 0.9141
# Epoch: [ 0] [  331/  468] time: 69.2233, train_loss: 0.23009540, train_accuracy: 0.9297, test_Accuracy: 0.9130
# Epoch: [ 0] [  332/  468] time: 69.4216, train_loss: 0.28435236, train_accuracy: 0.8984, test_Accuracy: 0.9130
# Epoch: [ 0] [  333/  468] time: 69.6218, train_loss: 0.41197157, train_accuracy: 0.8672, test_Accuracy: 0.9132
# Epoch: [ 0] [  334/  468] time: 69.8217, train_loss: 0.34377632, train_accuracy: 0.9219, test_Accuracy: 0.9137
# Epoch: [ 0] [  335/  468] time: 70.0266, train_loss: 0.32684314, train_accuracy: 0.8828, test_Accuracy: 0.9138
# Epoch: [ 0] [  336/  468] time: 70.2226, train_loss: 0.33645365, train_accuracy: 0.8906, test_Accuracy: 0.9131
# Epoch: [ 0] [  337/  468] time: 70.4298, train_loss: 0.21535487, train_accuracy: 0.9453, test_Accuracy: 0.9142
# Epoch: [ 0] [  338/  468] time: 70.6250, train_loss: 0.35565245, train_accuracy: 0.8984, test_Accuracy: 0.9142
# Epoch: [ 0] [  339/  468] time: 70.8301, train_loss: 0.41169295, train_accuracy: 0.8672, test_Accuracy: 0.9153
# Epoch: [ 0] [  340/  468] time: 71.0270, train_loss: 0.39020115, train_accuracy: 0.8906, test_Accuracy: 0.9162
# Epoch: [ 0] [  341/  468] time: 71.2343, train_loss: 0.20228127, train_accuracy: 0.9375, test_Accuracy: 0.9156
# Epoch: [ 0] [  342/  468] time: 71.4394, train_loss: 0.25465351, train_accuracy: 0.9297, test_Accuracy: 0.9154
# Epoch: [ 0] [  343/  468] time: 71.6349, train_loss: 0.32668191, train_accuracy: 0.9141, test_Accuracy: 0.9156
# Epoch: [ 0] [  344/  468] time: 71.8406, train_loss: 0.24796182, train_accuracy: 0.9453, test_Accuracy: 0.9151
# Epoch: [ 0] [  345/  468] time: 72.0486, train_loss: 0.22238603, train_accuracy: 0.9531, test_Accuracy: 0.9150
# Epoch: [ 0] [  346/  468] time: 72.2501, train_loss: 0.19271041, train_accuracy: 0.9531, test_Accuracy: 0.9154
# Epoch: [ 0] [  347/  468] time: 72.4479, train_loss: 0.32836467, train_accuracy: 0.9219, test_Accuracy: 0.9153
# Epoch: [ 0] [  348/  468] time: 72.6464, train_loss: 0.31385410, train_accuracy: 0.8984, test_Accuracy: 0.9151
# Epoch: [ 0] [  349/  468] time: 72.8467, train_loss: 0.37064135, train_accuracy: 0.8906, test_Accuracy: 0.9155
# Epoch: [ 0] [  350/  468] time: 73.0483, train_loss: 0.52276480, train_accuracy: 0.8672, test_Accuracy: 0.9164
# Epoch: [ 0] [  351/  468] time: 73.2607, train_loss: 0.26685685, train_accuracy: 0.9531, test_Accuracy: 0.9166
# Epoch: [ 0] [  352/  468] time: 73.4594, train_loss: 0.24525313, train_accuracy: 0.9453, test_Accuracy: 0.9171
# Epoch: [ 0] [  353/  468] time: 73.6809, train_loss: 0.28342038, train_accuracy: 0.9141, test_Accuracy: 0.9165
# Epoch: [ 0] [  354/  468] time: 73.8709, train_loss: 0.30094978, train_accuracy: 0.8906, test_Accuracy: 0.9164
# Epoch: [ 0] [  355/  468] time: 74.0718, train_loss: 0.34264457, train_accuracy: 0.8984, test_Accuracy: 0.9166
# Epoch: [ 0] [  356/  468] time: 74.2732, train_loss: 0.22521949, train_accuracy: 0.9609, test_Accuracy: 0.9170
# Epoch: [ 0] [  357/  468] time: 74.4777, train_loss: 0.22857779, train_accuracy: 0.9141, test_Accuracy: 0.9178
# Epoch: [ 0] [  358/  468] time: 74.6719, train_loss: 0.24384996, train_accuracy: 0.9219, test_Accuracy: 0.9178
# Epoch: [ 0] [  359/  468] time: 74.8758, train_loss: 0.20659934, train_accuracy: 0.9609, test_Accuracy: 0.9175
# Epoch: [ 0] [  360/  468] time: 75.0732, train_loss: 0.41045687, train_accuracy: 0.8438, test_Accuracy: 0.9178
# Epoch: [ 0] [  361/  468] time: 75.2972, train_loss: 0.44957131, train_accuracy: 0.8672, test_Accuracy: 0.9185
# Epoch: [ 0] [  362/  468] time: 75.4907, train_loss: 0.36356738, train_accuracy: 0.8750, test_Accuracy: 0.9172
# Epoch: [ 0] [  363/  468] time: 75.6990, train_loss: 0.34850264, train_accuracy: 0.9062, test_Accuracy: 0.9170
# Epoch: [ 0] [  364/  468] time: 75.9057, train_loss: 0.31232724, train_accuracy: 0.9062, test_Accuracy: 0.9172
# Epoch: [ 0] [  365/  468] time: 76.0960, train_loss: 0.27801910, train_accuracy: 0.9453, test_Accuracy: 0.9165
# Epoch: [ 0] [  366/  468] time: 76.3095, train_loss: 0.26929966, train_accuracy: 0.9375, test_Accuracy: 0.9172
# Epoch: [ 0] [  367/  468] time: 76.5184, train_loss: 0.26494300, train_accuracy: 0.9375, test_Accuracy: 0.9178
# Epoch: [ 0] [  368/  468] time: 76.7113, train_loss: 0.32022673, train_accuracy: 0.9062, test_Accuracy: 0.9165
# Epoch: [ 0] [  369/  468] time: 76.9167, train_loss: 0.44971117, train_accuracy: 0.8594, test_Accuracy: 0.9145
# Epoch: [ 0] [  370/  468] time: 77.1068, train_loss: 0.15163895, train_accuracy: 0.9688, test_Accuracy: 0.9136
# Epoch: [ 0] [  371/  468] time: 77.3063, train_loss: 0.34833211, train_accuracy: 0.8906, test_Accuracy: 0.9135
# Epoch: [ 0] [  372/  468] time: 77.4974, train_loss: 0.27625638, train_accuracy: 0.8906, test_Accuracy: 0.9149
# Epoch: [ 0] [  373/  468] time: 77.7102, train_loss: 0.29595301, train_accuracy: 0.9062, test_Accuracy: 0.9152
# Epoch: [ 0] [  374/  468] time: 77.8972, train_loss: 0.44942701, train_accuracy: 0.8984, test_Accuracy: 0.9170
# Epoch: [ 0] [  375/  468] time: 78.0988, train_loss: 0.40646896, train_accuracy: 0.8750, test_Accuracy: 0.9187
# Epoch: [ 0] [  376/  468] time: 78.2980, train_loss: 0.27818063, train_accuracy: 0.9141, test_Accuracy: 0.9191
# Epoch: [ 0] [  377/  468] time: 78.5030, train_loss: 0.29298440, train_accuracy: 0.8984, test_Accuracy: 0.9191
# Epoch: [ 0] [  378/  468] time: 78.6902, train_loss: 0.30920500, train_accuracy: 0.8828, test_Accuracy: 0.9201
# Epoch: [ 0] [  379/  468] time: 78.8866, train_loss: 0.24737146, train_accuracy: 0.9219, test_Accuracy: 0.9203
# Epoch: [ 0] [  380/  468] time: 79.0763, train_loss: 0.30194503, train_accuracy: 0.8906, test_Accuracy: 0.9196
# Epoch: [ 0] [  381/  468] time: 79.2825, train_loss: 0.26486242, train_accuracy: 0.9297, test_Accuracy: 0.9190
# Epoch: [ 0] [  382/  468] time: 79.4684, train_loss: 0.30237556, train_accuracy: 0.9219, test_Accuracy: 0.9193
# Epoch: [ 0] [  383/  468] time: 79.6663, train_loss: 0.26446027, train_accuracy: 0.9062, test_Accuracy: 0.9184
# Epoch: [ 0] [  384/  468] time: 79.8598, train_loss: 0.29712933, train_accuracy: 0.9453, test_Accuracy: 0.9166
# Epoch: [ 0] [  385/  468] time: 80.0599, train_loss: 0.28800079, train_accuracy: 0.9141, test_Accuracy: 0.9164
# Epoch: [ 0] [  386/  468] time: 80.2701, train_loss: 0.35679021, train_accuracy: 0.8906, test_Accuracy: 0.9170
# Epoch: [ 0] [  387/  468] time: 80.4701, train_loss: 0.24103755, train_accuracy: 0.9219, test_Accuracy: 0.9172
# Epoch: [ 0] [  388/  468] time: 80.6642, train_loss: 0.35816765, train_accuracy: 0.8984, test_Accuracy: 0.9176
# Epoch: [ 0] [  389/  468] time: 80.8653, train_loss: 0.30537736, train_accuracy: 0.9062, test_Accuracy: 0.9180
# Epoch: [ 0] [  390/  468] time: 81.0612, train_loss: 0.37568393, train_accuracy: 0.8828, test_Accuracy: 0.9182
# Epoch: [ 0] [  391/  468] time: 81.2667, train_loss: 0.19111629, train_accuracy: 0.9609, test_Accuracy: 0.9184
# Epoch: [ 0] [  392/  468] time: 81.4671, train_loss: 0.18982980, train_accuracy: 0.9375, test_Accuracy: 0.9178
# Epoch: [ 0] [  393/  468] time: 81.6785, train_loss: 0.25956795, train_accuracy: 0.9375, test_Accuracy: 0.9167
# Epoch: [ 0] [  394/  468] time: 81.8790, train_loss: 0.25016066, train_accuracy: 0.9141, test_Accuracy: 0.9170
# Epoch: [ 0] [  395/  468] time: 82.0904, train_loss: 0.23393145, train_accuracy: 0.9453, test_Accuracy: 0.9169
# Epoch: [ 0] [  396/  468] time: 82.2885, train_loss: 0.24857819, train_accuracy: 0.9141, test_Accuracy: 0.9169
# Epoch: [ 0] [  397/  468] time: 82.5013, train_loss: 0.32750815, train_accuracy: 0.8984, test_Accuracy: 0.9189
# Epoch: [ 0] [  398/  468] time: 82.6954, train_loss: 0.23165575, train_accuracy: 0.9375, test_Accuracy: 0.9209
# Epoch: [ 0] [  399/  468] time: 82.8957, train_loss: 0.28104943, train_accuracy: 0.9219, test_Accuracy: 0.9205
# Epoch: [ 0] [  400/  468] time: 83.1040, train_loss: 0.25515315, train_accuracy: 0.9375, test_Accuracy: 0.9200
# Epoch: [ 0] [  401/  468] time: 83.2941, train_loss: 0.28760940, train_accuracy: 0.9141, test_Accuracy: 0.9205
# Epoch: [ 0] [  402/  468] time: 83.4989, train_loss: 0.30517465, train_accuracy: 0.9062, test_Accuracy: 0.9205
# Epoch: [ 0] [  403/  468] time: 83.6941, train_loss: 0.16826391, train_accuracy: 0.9375, test_Accuracy: 0.9196
# Epoch: [ 0] [  404/  468] time: 83.9123, train_loss: 0.20078701, train_accuracy: 0.9453, test_Accuracy: 0.9198
# Epoch: [ 0] [  405/  468] time: 84.1212, train_loss: 0.26630741, train_accuracy: 0.9453, test_Accuracy: 0.9199
# Epoch: [ 0] [  406/  468] time: 84.3205, train_loss: 0.26223737, train_accuracy: 0.9297, test_Accuracy: 0.9206
# Epoch: [ 0] [  407/  468] time: 84.5233, train_loss: 0.26508796, train_accuracy: 0.9375, test_Accuracy: 0.9195
# Epoch: [ 0] [  408/  468] time: 84.7163, train_loss: 0.32915685, train_accuracy: 0.8984, test_Accuracy: 0.9193
# Epoch: [ 0] [  409/  468] time: 84.9120, train_loss: 0.25623694, train_accuracy: 0.9141, test_Accuracy: 0.9189
# Epoch: [ 0] [  410/  468] time: 85.1239, train_loss: 0.28960401, train_accuracy: 0.9219, test_Accuracy: 0.9189
# Epoch: [ 0] [  411/  468] time: 85.3206, train_loss: 0.24611387, train_accuracy: 0.9297, test_Accuracy: 0.9192
# Epoch: [ 0] [  412/  468] time: 85.5211, train_loss: 0.35545602, train_accuracy: 0.8672, test_Accuracy: 0.9197
# Epoch: [ 0] [  413/  468] time: 85.7188, train_loss: 0.26804239, train_accuracy: 0.9297, test_Accuracy: 0.9196
# Epoch: [ 0] [  414/  468] time: 85.9205, train_loss: 0.24522668, train_accuracy: 0.9297, test_Accuracy: 0.9203
# Epoch: [ 0] [  415/  468] time: 86.1187, train_loss: 0.29157111, train_accuracy: 0.9141, test_Accuracy: 0.9197
# Epoch: [ 0] [  416/  468] time: 86.3231, train_loss: 0.29294330, train_accuracy: 0.9141, test_Accuracy: 0.9205
# Epoch: [ 0] [  417/  468] time: 86.5390, train_loss: 0.20073451, train_accuracy: 0.9531, test_Accuracy: 0.9206
# Epoch: [ 0] [  418/  468] time: 86.7341, train_loss: 0.36812714, train_accuracy: 0.8828, test_Accuracy: 0.9211
# Epoch: [ 0] [  419/  468] time: 86.9412, train_loss: 0.23975097, train_accuracy: 0.9219, test_Accuracy: 0.9207
# Epoch: [ 0] [  420/  468] time: 87.1375, train_loss: 0.31826532, train_accuracy: 0.9141, test_Accuracy: 0.9208
# Epoch: [ 0] [  421/  468] time: 87.3385, train_loss: 0.20235506, train_accuracy: 0.9453, test_Accuracy: 0.9195
# Epoch: [ 0] [  422/  468] time: 87.5449, train_loss: 0.30809903, train_accuracy: 0.9062, test_Accuracy: 0.9190
# Epoch: [ 0] [  423/  468] time: 87.7438, train_loss: 0.22953545, train_accuracy: 0.9297, test_Accuracy: 0.9201
# Epoch: [ 0] [  424/  468] time: 87.9394, train_loss: 0.21856758, train_accuracy: 0.9219, test_Accuracy: 0.9214
# Epoch: [ 0] [  425/  468] time: 88.1530, train_loss: 0.28802922, train_accuracy: 0.8750, test_Accuracy: 0.9209
# Epoch: [ 0] [  426/  468] time: 88.3620, train_loss: 0.29146171, train_accuracy: 0.9062, test_Accuracy: 0.9213
# Epoch: [ 0] [  427/  468] time: 88.5611, train_loss: 0.15838933, train_accuracy: 0.9688, test_Accuracy: 0.9209
# Epoch: [ 0] [  428/  468] time: 88.7770, train_loss: 0.32514861, train_accuracy: 0.8984, test_Accuracy: 0.9208
# Epoch: [ 0] [  429/  468] time: 88.9734, train_loss: 0.33690837, train_accuracy: 0.9219, test_Accuracy: 0.9210
# Epoch: [ 0] [  430/  468] time: 89.1729, train_loss: 0.21366601, train_accuracy: 0.9297, test_Accuracy: 0.9211
# Epoch: [ 0] [  431/  468] time: 89.3800, train_loss: 0.23725295, train_accuracy: 0.9375, test_Accuracy: 0.9199
# Epoch: [ 0] [  432/  468] time: 89.5837, train_loss: 0.42806250, train_accuracy: 0.8828, test_Accuracy: 0.9202
# Epoch: [ 0] [  433/  468] time: 89.7775, train_loss: 0.28130308, train_accuracy: 0.9453, test_Accuracy: 0.9190
# Epoch: [ 0] [  434/  468] time: 89.9797, train_loss: 0.26089752, train_accuracy: 0.9141, test_Accuracy: 0.9198
# Epoch: [ 0] [  435/  468] time: 90.1712, train_loss: 0.26055312, train_accuracy: 0.9062, test_Accuracy: 0.9206
# Epoch: [ 0] [  436/  468] time: 90.3665, train_loss: 0.30356434, train_accuracy: 0.8906, test_Accuracy: 0.9211
# Epoch: [ 0] [  437/  468] time: 90.5677, train_loss: 0.30432943, train_accuracy: 0.8984, test_Accuracy: 0.9216
# Epoch: [ 0] [  438/  468] time: 90.7644, train_loss: 0.36017448, train_accuracy: 0.9141, test_Accuracy: 0.9231
# Epoch: [ 0] [  439/  468] time: 90.9600, train_loss: 0.50078404, train_accuracy: 0.8516, test_Accuracy: 0.9233
# Epoch: [ 0] [  440/  468] time: 91.1602, train_loss: 0.26354930, train_accuracy: 0.9219, test_Accuracy: 0.9231
# Epoch: [ 0] [  441/  468] time: 91.3579, train_loss: 0.23589756, train_accuracy: 0.9219, test_Accuracy: 0.9233
# Epoch: [ 0] [  442/  468] time: 91.5595, train_loss: 0.26988330, train_accuracy: 0.9375, test_Accuracy: 0.9238
# Epoch: [ 0] [  443/  468] time: 91.7565, train_loss: 0.20420733, train_accuracy: 0.9453, test_Accuracy: 0.9250
# Epoch: [ 0] [  444/  468] time: 91.9496, train_loss: 0.24504602, train_accuracy: 0.9453, test_Accuracy: 0.9244
# Epoch: [ 0] [  445/  468] time: 92.1418, train_loss: 0.32594943, train_accuracy: 0.8906, test_Accuracy: 0.9249
# Epoch: [ 0] [  446/  468] time: 92.3390, train_loss: 0.27567339, train_accuracy: 0.9141, test_Accuracy: 0.9241
# Epoch: [ 0] [  447/  468] time: 92.5336, train_loss: 0.19806607, train_accuracy: 0.9609, test_Accuracy: 0.9245
# Epoch: [ 0] [  448/  468] time: 92.7262, train_loss: 0.35845292, train_accuracy: 0.8906, test_Accuracy: 0.9251
# Epoch: [ 0] [  449/  468] time: 92.9174, train_loss: 0.16140880, train_accuracy: 0.9531, test_Accuracy: 0.9255
# Epoch: [ 0] [  450/  468] time: 93.1175, train_loss: 0.32239980, train_accuracy: 0.9141, test_Accuracy: 0.9266
# Epoch: [ 0] [  451/  468] time: 93.3074, train_loss: 0.15660781, train_accuracy: 0.9766, test_Accuracy: 0.9269
# Epoch: [ 0] [  452/  468] time: 93.5137, train_loss: 0.28130496, train_accuracy: 0.9297, test_Accuracy: 0.9264
# Epoch: [ 0] [  453/  468] time: 93.7105, train_loss: 0.29966968, train_accuracy: 0.9141, test_Accuracy: 0.9263
# Epoch: [ 0] [  454/  468] time: 93.9064, train_loss: 0.17018205, train_accuracy: 0.9688, test_Accuracy: 0.9261
# Epoch: [ 0] [  455/  468] time: 94.1104, train_loss: 0.19641054, train_accuracy: 0.9219, test_Accuracy: 0.9251
# Epoch: [ 0] [  456/  468] time: 94.3177, train_loss: 0.25511679, train_accuracy: 0.9453, test_Accuracy: 0.9246
# Epoch: [ 0] [  457/  468] time: 94.5468, train_loss: 0.34149775, train_accuracy: 0.8984, test_Accuracy: 0.9239
# Epoch: [ 0] [  458/  468] time: 94.7450, train_loss: 0.26126987, train_accuracy: 0.9297, test_Accuracy: 0.9241
# Epoch: [ 0] [  459/  468] time: 94.9456, train_loss: 0.37579253, train_accuracy: 0.8906, test_Accuracy: 0.9240
# Epoch: [ 0] [  460/  468] time: 95.1352, train_loss: 0.30111685, train_accuracy: 0.8984, test_Accuracy: 0.9245
# Epoch: [ 0] [  461/  468] time: 95.3396, train_loss: 0.30019897, train_accuracy: 0.9141, test_Accuracy: 0.9245
# Epoch: [ 0] [  462/  468] time: 95.5381, train_loss: 0.15059470, train_accuracy: 0.9531, test_Accuracy: 0.9248
# Epoch: [ 0] [  463/  468] time: 95.7365, train_loss: 0.28558320, train_accuracy: 0.9141, test_Accuracy: 0.9252
# Epoch: [ 0] [  464/  468] time: 95.9344, train_loss: 0.18268761, train_accuracy: 0.9375, test_Accuracy: 0.9243
# Epoch: [ 0] [  465/  468] time: 96.1357, train_loss: 0.30111262, train_accuracy: 0.8984, test_Accuracy: 0.9237
# Epoch: [ 0] [  466/  468] time: 96.3325, train_loss: 0.33366939, train_accuracy: 0.8984, test_Accuracy: 0.9235
# Epoch: [ 0] [  467/  468] time: 96.5422, train_loss: 0.20679554, train_accuracy: 0.9219, test_Accuracy: 0.9220
